# %% [markdown]
# <a href="https://colab.research.google.com/github/marpitkumar/Admin_UI/blob/main/ott.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/data_ott.csv')

# %%
df.head()
# Out:
#     s366    Movie                  Eyes of a Thief        Najwa Najjar  \
# 0   s276  TV Show                      The Kingdom                 NaN
# 1   s435  TV Show                           Okupas                 NaN
# 2   s674  TV Show                No Time for Shame                 NaN
# 3  s1734  TV Show  Carmel: Who Killed Maria Marta?  Alejandro Hartmann
# 4  s1918  TV Show            Secreto bien guardado                 NaN
#
#   Khaled Abol El Naga, Souad Massi, Suhail Haddad, Malak Ermileh, Maisa Abd Elhadi, Walid Abdul Salam, Nisreen Faour, Areen Omari  \
# 0  Chino Darín, Nancy Dupláa, Joaquín Furriel, Pe...
# 1  Rodrigo de la Serna, Diego Alonso, Ariel Stalt...
# 2                                   Santiago Artemis
# 3                                                NaN
# 4  Oriana Sabatini, Victorio D'Alessandro, Noemí ...
#
#      Algeria     July 30, 2021  2014  TV-14   103 min  \
# 0  Argentina   August 13, 2021  2021  TV-MA  1 Season
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                   --------------  -----
#  0   s366                                                                                                                                     8807 non-null   object
#  1   Movie                                                                                                                                    8807 non-null   object
#  2   Eyes of a Thief                                                                                                                          8807 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Movie'].unique()
# Out:
# array(['TV Show', 'Movie', 'type'], dtype=object)

# %%
sns.countplot(df['Movie'])
# Out:
# <Axes: xlabel='count', ylabel='Movie'>

# %%
sns.heatmap(df.isna(),cmap = 'Greens')
# Out:
# <Axes: >
